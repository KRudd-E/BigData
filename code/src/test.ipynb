# %%
# data_ingestion.py

"""
data_ingestion.py

This module shall handle loading raw data and returns a Spark DataFrame for subsequent stages of the pipeline.
"""

from pyspark.sql import SparkSession
from pyspark.sql import DataFrame
from pyspark.sql.types import StructType, StructField, IntegerType, DoubleType
import os
# THIS WAS HERE IN BEN'S DODGY COMMIT

class DataIngestion:
    """
    Responsible for:       
        1. Loading data.
        2. Performing basic validations or sanity checks.
        3. Returning the loaded data in a Spark-dataframe format.
    """

    def __init__(self, spark: SparkSession, config: dict):
        """
        Set up Spark session and configuration.

        Args:
            spark (SparkSession): Spark session to be used for reading data.
            config (dict): Dictionary containing settings for data paths,
                           file formats, and any other parameters.
        """
        self.spark = spark
        config.setdefault("data_percentage", 1.0)
        self.config = config


    def load_data(self):
        """Load data using file path from config."""
        data_path = self.config["data_path"]
        data_percentage = self.config["data_percentage"]
        
        print(f"Data Path is {data_path} and loading {data_percentage}% of data ++++++++++++++++++++++")

        columns = [f"_c{i}" for i in range(1, 141)]
        schema = StructType([
            StructField("label", IntegerType(), True)
        ] + [
            StructField(col, DoubleType(), True) for col in columns
        ])
        df = self.spark.read.csv(
            data_path, 
            header=True, 
            schema=schema, 
            sep=","
        )
        # df = df.sample(fraction=data_percentage)     
        print(f"\nData size is :{df.count()}\n")
        self.validate_data(df)  # Check if data is valid.
        return df
    

    def validate_data(self, df):
        """Make sure the data is not empty."""
        # fetch a single row and check if the list is empty
        if len(df.take(1)) == 0:
            raise Exception("Data is empty!")
        
    def get_sample_data(self, df, fraction=0.1):
        """Return a small random sample of the data for testing."""
        return df.sample(fraction=fraction)

# %%
from pyspark.sql import SparkSession

if "DATABRICKS_RUNTIME_VERSION" in os.environ:
    try:
        spark  # Try to use the existing 'spark' session.
        print("\nUsing Databricks Spark session.")
    except NameError:
        spark = SparkSession.builder.getOrCreate()
        print("\nDatabricks: Created Spark session!")
    config_DataIngestion = {
        "data_path": "/mnt/2025-team6/fulldataset_ECG5000.csv",
        "data_percentage": 0.005  # % Percentage of data to load for SW development
    }
else:
    # If not in Databricks, we are running locally.
    # Try to get an active Spark session; if none, create one.
    spark = SparkSession.getActiveSession()
    if spark is None:
        spark = SparkSession.builder \
            .appName("TestPipeline") \
            .master("local[*]") \
            .getOrCreate()
        print("\nLocal: Created Spark session!")
    else:
        print("\nLocal: Spark session already active!")
# Out:
# Local: Created Spark session!

# %%
current_dir = os.getcwd()
# Go up two levels to reach the project root
project_root = os.path.abspath(os.path.join(current_dir, "..", ".."))

config_DataIngestion = {
    # "data_path": project_root + "/ECG5000/*.tsv" # IF WE DECIDE TO USE .tsv FILES
    "data_path": project_root + "/fulldataset_ECG5000.csv", # IF WE DECIDE TO USE .csv FILES
    "data_percentage": 0.005  # % Percentage of data to load for SW development
    }   

ingestion = DataIngestion(spark, config_DataIngestion)

# %%
config_DataIngestion['data_path']
# Out:
# 'c:\\Users\\benat\\OneDrive\\0. MSc MLiS\\0. GitHub Repositories\\BigDataProject_repo/fulldataset_ECG5000.csv'

# %%
df_full = ingestion.load_data()
# df.show()
df_full.count()

df_subset = ingestion.get_sample_data(df_full, fraction=0.1)
df_subset.count()
# Out:
# Data Path is c:\Users\benat\OneDrive\0. MSc MLiS\0. GitHub Repositories\BigDataProject_repo/fulldataset_ECG5000.csv and loading 0.005% of data ++++++++++++++++++++++
#
# Data size is :5000
# 501

# %%
import pyspark.sql.functions as F

# %%
df = df_full
feature_cols = [col for col in df.columns if col != "label"]
feature_cols[:5]
# Out:
# ['_c1', '_c2', '_c3', '_c4', '_c5']

# %%
col_exprs = []
for col in feature_cols:
    col_exprs.append(F.min(col))
    col_exprs.append(F.max(col))

col_exprs[:5]
# Out:
# [Column<'min(_c1)'>,
#  Column<'max(_c1)'>,
#  Column<'min(_c2)'>,
#  Column<'max(_c2)'>,
#  Column<'min(_c3)'>]

# %%
df_stats_rows = df.select(*col_exprs)

print(df_stats_rows.first())
print(df_stats_rows.show(5, truncate=False))
# Out:
# Row(min(_c1)=-6.7294987, max(_c1)=4.9664142, min(_c2)=-7.0903741, max(_c2)=3.4796887, min(_c3)=-5.1324592, max(_c3)=2.660597, min(_c4)=-5.3632414, max(_c4)=1.8997982, min(_c5)=-5.3757152, max(_c5)=2.1470148, min(_c6)=-5.3301935, max(_c6)=1.6143748, min(_c7)=-4.7822402, max(_c7)=1.8687283, min(_c8)=-4.3112877, max(_c8)=1.804251, min(_c9)=-4.071361, max(_c9)=1.68373, min(_c10)=-4.1424756, max(_c10)=1.8986267, min(_c11)=-4.0405259, max(_c11)=2.0330067, min(_c12)=-3.7245377, max(_c12)=2.1598611, min(_c13)=-3.264576, max(_c13)=2.3908666, min(_c14)=-3.2223453, max(_c14)=2.433236, min(_c15)=-3.2634838, max(_c15)=2.1603562, min(_c16)=-3.2192115, max(_c16)=2.1257583, min(_c17)=-3.2021869, max(_c17)=2.5667622, min(_c18)=-3.1475037, max(_c18)=2.0997268, min(_c19)=-3.4599173, max(_c19)=2.1175937, min(_c20)=-4.1021017, max(_c20)=2.0762789, min(_c21)=-4.3112405, max(_c21)=2.0531319, min(_c22)=-4.0998883, max(_c22)=2.0917938, min(_c23)=-3.6149732, max(_c23)=2.0032581, min(_c24)=-3.8222981, max(_c24)=1.9506229, min(_c25)=-3.795567, max(_c25)=1.9584021, min(_c26)=-3.6908174, max(_c26)=1.9668383, min(_c27)=-3.5424851, max(_c27)=1.9415705, min(_c28)=-3.6316648, max(_c28)=1.9646785, min(_c29)=-3.5871118, max(_c29)=1.8668972, min(_c30)=-3.4522153, max(_c30)=1.8702576, min(_c31)=-4.074752, max(_c31)=1.862162, min(_c32)=-4.137454, max(_c32)=2.0632647, min(_c33)=-4.0596621, max(_c33)=1.9411096, min(_c34)=-3.6266463, max(_c34)=1.9310911, min(_c35)=-2.8294709, max(_c35)=1.8902011, min(_c36)=-3.5858662, max(_c36)=1.8344719, min(_c37)=-4.0034009, max(_c37)=1.721037, min(_c38)=-3.9007239, max(_c38)=1.6193009, min(_c39)=-3.3253292, max(_c39)=1.5838243, min(_c40)=-3.9110931, max(_c40)=1.6135332, min(_c41)=-4.8624432, max(_c41)=1.6003003, min(_c42)=-4.7102681, max(_c42)=1.6290253, min(_c43)=-4.238206, max(_c43)=1.9094171, min(_c44)=-4.2479357, max(_c44)=1.4639054, min(_c45)=-3.8927817, max(_c45)=1.5743154, min(_c46)=-3.1359496, max(_c46)=1.5367255, min(_c47)=-3.0100917, max(_c47)=1.7531018, min(_c48)=-2.9518917, max(_c48)=1.6130151, min(_c49)=-3.1790571, max(_c49)=1.5249605, min(_c50)=-3.4346997, max(_c50)=1.518558, min(_c51)=-3.2435546, max(_c51)=1.7237147, min(_c52)=-3.1847895, max(_c52)=2.01083, min(_c53)=-3.2049952, max(_c53)=2.2446936, min(_c54)=-3.2982423, max(_c54)=2.3218288, min(_c55)=-3.1828446, max(_c55)=2.3148718, min(_c56)=-3.1191348, max(_c56)=2.3313995, min(_c57)=-3.1322611, max(_c57)=2.3148302, min(_c58)=-3.2630806, max(_c58)=2.1654538, min(_c59)=-4.0393168, max(_c59)=1.9565594, min(_c60)=-4.2750366, max(_c60)=2.1020668, min(_c61)=-3.9420415, max(_c61)=2.1482104, min(_c62)=-3.7741892, max(_c62)=2.1189173, min(_c63)=-3.9655059, max(_c63)=2.0377493, min(_c64)=-4.2753339, max(_c64)=1.9914664, min(_c65)=-4.0059776, max(_c65)=2.0010931, min(_c66)=-3.01589, max(_c66)=1.9671515, min(_c67)=-2.6625521, max(_c67)=1.8619448, min(_c68)=-2.877228, max(_c68)=1.7395333, min(_c69)=-2.9865481, max(_c69)=1.6135791, min(_c70)=-2.8793224, max(_c70)=1.5187846, min(_c71)=-2.7151453, max(_c71)=1.4396798, min(_c72)=-2.6235346, max(_c72)=1.6916075, min(_c73)=-2.4703009, max(_c73)=1.9726253, min(_c74)=-2.1337404, max(_c74)=1.8264849, min(_c75)=-1.9863325, max(_c75)=1.5329315, min(_c76)=-2.2182942, max(_c76)=1.5110082, min(_c77)=-2.449467, max(_c77)=1.8348545, min(_c78)=-2.6624586, max(_c78)=2.0508222, min(_c79)=-2.8088536, max(_c79)=2.0379966, min(_c80)=-2.8724661, max(_c80)=1.7736018, min(_c81)=-2.8676527, max(_c81)=1.6152924, min(_c82)=-2.8127518, max(_c82)=1.7256453, min(_c83)=-2.7143838, max(_c83)=2.2100626, min(_c84)=-2.5832347, max(_c84)=2.4154315, min(_c85)=-2.4471303, max(_c85)=2.6481224, min(_c86)=-2.4349978, max(_c86)=2.7348561, min(_c87)=-2.7269236, max(_c87)=2.6803758, min(_c88)=-2.932931, max(_c88)=2.5134884, min(_c89)=-3.0221297, max(_c89)=2.3942933, min(_c90)=-2.9356801, max(_c90)=2.3146068, min(_c91)=-2.8197188, max(_c91)=2.5053988, min(_c92)=-2.7362329, max(_c92)=2.539237, min(_c93)=-2.7366691, max(_c93)=2.443274, min(_c94)=-3.1447293, max(_c94)=2.5302 ...
# +----------+---------+----------+---------+----------+--------+----------+---------+----------+---------+----------+---------+----------+---------+----------+--------+---------+--------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# |min(_c1)  |max(_c1) |min(_c2)  |max(_c2) |min(_c3)  |max(_c3)|min(_c4)  |max(_c4) |min(_c5)  |max(_c5) |min(_c6)  |max(_c6) |min(_c7)  |max(_c7) |min(_c8)  |max(_c8)|min(_c9) |max(_c9)|min(_c10) |max(_c10)|min(_c11) |max(_c11)|min(_c12) |max(_c12)|min(_c13)|max(_c13)|min(_c14) |max(_c14)|min(_c15) |max(_c15)|min(_c16) |max(_c16)|min(_c17) |max(_c17)|min(_c18) |max(_c18)|min(_c19) |max(_c19)|min(_c20) |max(_c20)|min(_c21) |max(_c21)|min(_c22) |max(_c22)|min(_c23) |max(_c23)|min(_c24) |max(_c24)|min(_c25)|max(_c25)|min(_c26) |max(_c26)|min(_c27) |max(_c27)|min(_c28) |max(_c28)|min(_c29) |max(_c29)|min(_c30) |max(_c30)|min(_c31)|max(_c31)|min(_c32)|max(_c32)|min(_c33) |max(_c33)|min(_c34) |max(_c34)|min(_c35) |max(_c35)|min(_c36) |max(_c36)|min(_c37) |max(_c37)|min(_c38) |max(_c38)|min(_c39) |max(_c39)|min(_c40) |max(_c40)|min(_c41) |max(_c41)|min(_c42) |max(_c42)|min(_c43)|max(_c43)|min(_c44) |max(_c44)|min(_c45) |max(_c45)|min(_c46) |max(_c46)|min(_c47) |max(_c47)|min(_c48) |max(_c48)|min(_c49) |max(_c49)|min(_c50) |max(_c50)|min(_c51) |max(_c51)|min(_c52) |max(_c52)|min(_c53) |max(_c53)|min(_c54) |max(_c54)|min(_c55) |max(_c55)|min(_c56) |max(_c56)|min(_c57) |max(_c57)|min(_c58) |max(_c58)|min(_c59) |max(_c59)|min(_c60) |max(_c60)|min(_c61) |max(_c61)|min(_c62) |max(_c62)|min(_c63) |max(_c63)|min(_c64) |max(_c64)|min(_c65) |max(_c65)|min(_c66)|max(_c66)|min(_c67) |max(_c67)|min(_c68)|max(_c68)|min(_c69) |max(_c69)|min(_c70) |max(_c70)|min(_c71) |max(_c71)|min(_c72) |max(_c72)|min(_c73) |max(_c73)|min(_c74) |max(_c74)|min(_c75) |max(_c75)|min(_c76) |max(_c76)|min(_c77)|max(_c77)|min(_c78) |max(_c78)|min(_c79) |max(_c79)|min(_c80) |max(_c80)|min(_c81) |max(_c81)|min(_c82) |max(_c82)|min(_c83) |max(_c83)|min(_c84) |max(_c84)|min(_c85) |max(_c85)|min(_c86) |max(_c86)|min(_c87) |max(_c87)|min(_c88)|max(_c88)|min(_c89) |max(_c89)|min(_c90) |max(_c90)|min(_c91) |max(_c91)|min(_c92) |max(_c92)|min(_c93) |max(_c93)|min(_c94) |max(_c94)|min(_c95) |max(_c95)|min(_c96) |max(_c96)|min(_c97) |max(_c97)|min(_c98) |max(_c98)|min(_c99) |max(_c99)|min(_c100)|max(_c100)|min(_c101)|max(_c101)|min(_c102)|max(_c102)|min(_c103)|max(_c103)|min(_c104)|max(_c104)|min(_c105)|max(_c105)|min(_c106)|max(_c106)|min(_c107)|max(_c107)|min(_c108)|max(_c108)|min(_c109)|max(_c109)|min(_c110)|max(_c110)|min(_c111)|max(_c111)|min(_c112)|max(_c112)|min(_c113)|max(_c113)|min(_c114)|max(_c114)|min(_c115)|max(_c115)|min(_c116)|max(_c116)|min(_c117)|max(_c117)|min(_c118)|max(_c118)|min(_c119)|max(_c119)|min(_c120)|max(_c120)|min(_c121)|max(_c121)|min(_c122)|max(_c122)|min(_c123)|max(_c123)|min(_c124)|max(_c124)|min(_c125)|max(_c125)|min(_c126)|max(_c126)|min(_c127)|max(_c127)|min(_c128)|max(_c128)|min(_c129)|max(_c129)|min(_c130)|max(_c130)|min(_c131)|max(_c131)|min(_c132)|max(_c132)|min(_c133)|max(_c133)|min(_c134)|max(_c134)|min(_c135)|max(_c135)|min(_c136)|max(_c136)|min(_c137)|max(_c137)|min(_c138)|max(_c138)|min(_c139)|max(_c139)|min(_c140)|max(_c140)|
# +----------+---------+----------+---------+----------+--------+----------+---------+----------+---------+----------+---------+----------+---------+----------+--------+---------+--------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# |-6.7294987|4.9664142|-7.0903741|3.4796887|-5.1324592|2.660597|-5.3632414|1.8997982|-5.3757152|2.1470148|-5.3301935|1.6143748|-4.7822402|1.8687283|-4.3112877|1.804251|-4.071361|1.68373 |-4.1424756|1.8986267|-4.0405259|2.0330067|-3.7245377|2.1598611|-3.264576|2.3908666|-3.2223453|2.433236 |-3.2634838|2.1603562|-3.2192115|2.1257583|-3.2021869|2.5667622|-3.1475037|2.0997268|-3.4599173|2.1175937|-4.1021017|2.0762789|-4.3112405|2.0531319|-4.0998883|2.0917938|-3.6149732|2.0032581|-3.8222981|1.9506229|-3.795567|1.9584021|-3.6908174|1.9668383|-3.5424851|1.9415705|-3.6316648|1.9646785|-3.5871118|1.8668972|-3.4522153|1.8702576|-4.074752|1.862162 |-4.137454|2.0632647|-4.0596621|1.9411096|-3.6266463|1.9310911|-2.8294709|1.8902011|-3.5858662|1.8344719|-4.0034009|1.721037 |-3.9007239|1.6193009|-3.3253292|1.5838243|-3.9110931|1.6135332|-4.8624432|1.6003003|-4.7102681|1.6290253|-4.238206|1.9094171|-4.2479357|1.4639054|-3.8927817|1.5743154|-3.1359496|1.5367255|-3.0100917|1.7531018|-2.9518917|1.6130151|-3.1790571|1.5249605|-3.4346997|1.518558 |-3.2435546|1.7237147|-3.1847895|2.01083  |-3.2049952|2.2446936|-3.2982423|2.3218288|-3.1828446|2.3148718|-3.1191348|2.3313995|-3.1322611|2.3148302|-3.2630806|2.1654538|-4.0393168|1.9565594|-4.2750366|2.1020668|-3.9420415|2.1482104|-3.7741892|2.1189173|-3.9655059|2.0377493|-4.2753339|1.9914664|-4.0059776|2.0010931|-3.01589 |1.9671515|-2.6625521|1.8619448|-2.877228|1.7395333|-2.9865481|1.6135791|-2.8793224|1.5187846|-2.7151453|1.4396798|-2.6235346|1.6916075|-2.4703009|1.9726253|-2.1337404|1.8264849|-1.9863325|1.5329315|-2.2182942|1.5110082|-2.449467|1.8348545|-2.6624586|2.0508222|-2.8088536|2.0379966|-2.8724661|1.7736018|-2.8676527|1.6152924|-2.8127518|1.7256453|-2.7143838|2.2100626|-2.5832347|2.4154315|-2.4471303|2.6481224|-2.4349978|2.7348561|-2.7269236|2.6803758|-2.932931|2.5134884|-3.0221297|2.3942933|-2.9356801|2.3146068|-2.8197188|2.5053988|-2.7362329|2.539237 |-2.7366691|2.443274 |-3.1447293|2.5302014|-3.2585025|2.8701469|-3.2138933|2.9537738|-3.3642969|2.6632165|-3.3240152|2.4607266|-3.1609757|2.3928849|-2.9301062|2.8800888 |-2.6621695|2.942679  |-2.6349502|2.8367674 |-2.6347679|2.8206159 |-2.5916626|2.9401538 |-2.4464764|2.6857256 |-2.2341747|2.9593237 |-2.4314027|2.8955722 |-2.6816037|2.6048232 |-2.8647064|2.478775  |-3.4156562|2.5133282 |-3.4976237|2.5998917 |-3.0912823|2.9371519 |-2.6085103|2.9505222 |-2.3832037|2.8308516 |-2.6788827|2.8617811 |-3.305661 |2.8287754 |-3.17959  |2.7028567 |-3.311559 |2.5384372 |-3.5015552|2.6802031 |-4.0072121|2.7640174 |-4.1995626|2.8397101 |-3.3356775|2.7145483 |-3.1276028|2.8695417 |-3.0425319|3.0523766 |-3.1161769|3.1418084 |-3.9723196|3.2151351 |-4.7540569|3.1987902 |-4.2900157|3.0861373 |-3.8024689|3.1571566 |-4.0146424|3.0370783 |-3.9717152|2.9609691 |-4.1670404|3.0076062 |-4.5575762|2.8546803 |-4.5304884|2.9123944 |-4.5632696|2.9376849 |-5.1500997|3.3514369 |-4.8804596|3.4325185 |-5.4961075|3.5794483 |-5.8808898|4.4259762 |-6.0922269|7.4021031 |
# +----------+---------+----------+---------+----------+--------+----------+---------+----------+---------+----------+---------+----------+---------+----------+--------+---------+--------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+---------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+---------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
#
# None
