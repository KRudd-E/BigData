# %%
import pandas as pd
import matplotlib.pyplot as plt

from aeon.datasets import load_classification
X, y = load_classification("ECG5000")

print(X.shape,  y.shape)

train_data = pd.read_csv('data/ECG5000/ECG5000_TRAIN.tsv', sep='\t', header=None, index_col=0)
test_data  = pd.read_csv('data/ECG5000/ECG5000_TEST.tsv', sep='\t', header=None,  index_col=0)

print(f'train_data shape:{train_data.shape}\ntest_data shape:{test_data.shape}\n')
# Out:
# (5000, 1, 140) (5000,)
# train_data shape:(500, 140)
# test_data shape:(4500, 140)

# %%
train_cols = train_data.columns.values / 
row0 = train_data.iloc[0].values *10

plt.figure(figsize=(8, 6))
plt.plot(train_cols, row0)
plt.xlabel('Time')
plt.ylabel('Voltage (mV)')
plt.title('Single Row Data Plot')
plt.show()
